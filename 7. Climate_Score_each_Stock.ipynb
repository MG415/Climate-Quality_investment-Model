# %%
# Initial Imports:
import pandas as pd
import numpy as np
import os
from datetime import datetime

# To run models:
from xgboost import XGBRegressor, XGBClassifier
from sklearn.metrics import (r2_score, 
                             ConfusionMatrixDisplay, 
                             accuracy_score, 
                             precision_score, 
                             recall_score, 
                             f1_score)

# %%
BASE_DIR = os.path.abspath(os.path.dirname('__file__'))

all_data  = pd.read_csv('all_data.csv', index_col='Date', parse_dates=True)

# %%
all_data.head()
# Out:
#             Mkt-RF     SMB     HML     RMW     CMA      RF  cdd_18-France  \
# Date
# 2015-09-30 -0.0307 -0.0280  0.0056  0.0180 -0.0060  0.0000        7.58800
# 2015-10-31  0.0775 -0.0205 -0.0046  0.0086  0.0055  0.0000        0.59810
# 2015-11-30  0.0056  0.0329 -0.0042 -0.0271 -0.0103  0.0000        0.01212
# 2015-12-31 -0.0217 -0.0297 -0.0261  0.0045  0.0003  0.0001        0.00000
# 2016-01-31 -0.0577 -0.0348  0.0209  0.0280  0.0307  0.0001        0.00000
#
#             cdd_18-Germany  cdd_18-India  cdd_18-Indonesia  ...   ret_ETN  \
# Date                                                        ...
# 2015-09-30           1.484        313.40             233.8  ...       NaN
# 2015-10-31           0.000        280.10             263.1  ...  0.000000
# 2015-11-30           0.000        169.60             256.0  ...  0.144820
# 2015-12-31           0.000         88.83             250.7  ... -0.105227
# 2016-01-31           0.000         72.22             260.8  ...  0.000000
#
#             ret_GOOGL    ret_HD   ret_HIG    ret_MS  ret_MSFT   ret_PLD  \
# Date
# 2015-09-30        NaN       NaN       NaN       NaN       NaN       NaN
# 2015-10-31   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2015-11-30   0.194997  0.159235  0.001563  0.093980  0.236248  0.098971
# 2015-12-31   0.019873 -0.007803 -0.047765 -0.072595  0.020791  0.013633
# 2016-01-31   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#               ret_TT   ret_UNH     ret_V
# Date
# 2015-09-30       NaN       NaN       NaN
# 2015-10-31  0.000000  0.000000  0.000000
# 2015-11-30  0.155604 -0.028446  0.136261
# 2015-12-31 -0.052648  0.048249 -0.018478
# 2016-01-31  0.000000  0.000000  0.000000
#
# [5 rows x 120 columns]

# %%
all_data = all_data.iloc[1:,]
all_data = all_data.ffill()

# %%
stock_list = ['ret_AAPL', 'ret_APTV', 'ret_BAC', 'ret_BALL', 'ret_BEP', 'ret_BKNG', 
              'ret_BMRN', 'ret_COST', 'ret_CVS', 'ret_DE', 'ret_ETN', 'ret_GOOGL', 'ret_HD', 
              'ret_HIG', 'ret_MS', 'ret_MSFT', 'ret_PLD', 'ret_TT', 'ret_UNH', 'ret_V']

# %%
for i in stock_list:
    all_data[i] = np.where(all_data[i] > 0, 1, 0) # 'Long = 1', 'Short = -1'

# %% [markdown]
# # example : Create C_Score for AAPL

# %% [markdown]
# ### Note! C_score is climate score for each stock

# %%
# Define X and y variables:
X = all_data.drop(stock_list, axis=1)
X = X.drop('ret_Fund' ,axis=1)
y = all_data.loc[:, 'ret_AAPL']

# %%
# Split into Training/Testing Data:
split = int(0.8 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
clf = XGBClassifier(booster = 'gbtree', 
                    objective = 'binary:logistic',
                    gamma = 0.05,
                    colsample_bytree = 0.8,
                    colsample_bynode = 0.5,
                    n_estimators = 200, 
                    subsample = 0.8, 
                    min_child_weight = 1, 
                    learning_rate = 0.1)

# %%
# %%time
clf.fit(X_train, y_train)
# Out:
# CPU times: user 2.31 s, sys: 27 ms, total: 2.33 s
# Wall time: 218 ms
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=0.5,
#               colsample_bytree=0.8, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.05, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=200, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
predictions = clf.predict(X)

# %%
accuracy_score(y, predictions)
# Out:
# 0.9310344827586207

# %%
precision_score(y, predictions, pos_label=0)
# Out:
# 0.9565217391304348

# %%
precision_score(y, predictions, pos_label=1)
# Out:
# 0.9024390243902439

# %%
recall_score(y, predictions, pos_label=0)
# Out:
# 0.9166666666666666

# %%
recall_score(y, predictions, pos_label=1)
# Out:
# 0.9487179487179487

# %% [markdown]
# # Calculate C_Score for all stock

# %%
stock_list = ['AAPL', 'APTV', 'BAC', 'BALL', 'BEP', 'BKNG', 'BMRN', 'COST', 'CVS', 'DE', 'ETN', 'GOOGL', 'HD', 'HIG', 'MS', 'MSFT', 'PLD', 'TT', 'UNH', 'V']

# %%
# %%time
for i in stock_list:
    # Define X and y variables:
    X = all_data.drop(stock_list, axis=1)
    X = X.drop('ret_Fund' ,axis=1)
    y = all_data.loc[:, 'ret_'+i]

    # Split into Training/Testing Data:
    split = int(0.8 * len(X))
    X_train = X[: split]
    X_test = X[split:]
    y_train = y[: split]
    y_test = y[split:]

    clf = XGBClassifier(booster = 'gbtree', 
                        objective = 'binary:logistic',
                        gamma = 0.05,
                        colsample_bytree = 0.8,
                        colsample_bynode = 0.5,
                        n_estimators = 200, 
                        subsample = 0.8, 
                        min_child_weight = 1, 
                        learning_rate = 0.1)
    clf.fit(X_train, y_train)
    predictions = clf.predict(X)
    all_data['C_Score_'+i] = predictions
# Out:
# CPU times: user 53.5 s, sys: 155 ms, total: 53.7 s
# Wall time: 5.09 s

# %%
all_data.head()
# Out:
#             Mkt-RF     SMB     HML     RMW     CMA      RF  cdd_18-France  \
# Date
# 2015-10-31  0.0775 -0.0205 -0.0046  0.0086  0.0055  0.0000        0.59810
# 2015-11-30  0.0056  0.0329 -0.0042 -0.0271 -0.0103  0.0000        0.01212
# 2015-12-31 -0.0217 -0.0297 -0.0261  0.0045  0.0003  0.0001        0.00000
# 2016-01-31 -0.0577 -0.0348  0.0209  0.0280  0.0307  0.0001        0.00000
# 2016-02-29 -0.0007  0.0085 -0.0057  0.0328  0.0199  0.0002        0.00000
#
#             cdd_18-Germany  cdd_18-India  cdd_18-Indonesia  ...  C_Score_ETN  \
# Date                                                        ...
# 2015-10-31             0.0        280.10             263.1  ...            0
# 2015-11-30             0.0        169.60             256.0  ...            1
# 2015-12-31             0.0         88.83             250.7  ...            0
# 2016-01-31             0.0         72.22             260.8  ...            0
# 2016-02-29             0.0        142.20             230.0  ...            1
#
#             C_Score_GOOGL  C_Score_HD  C_Score_HIG  C_Score_MS  C_Score_MSFT  \
# Date
# 2015-10-31              0           0            0           0             0
# 2015-11-30              1           1            1           1             1
# 2015-12-31              1           0            0           0             1
# 2016-01-31              0           0            0           0             0
# 2016-02-29              0           0            0           0             0
#
#             C_Score_PLD  C_Score_TT  C_Score_UNH  C_Score_V
# Date
# 2015-10-31            0           0            0          0
# 2015-11-30            1           1            0          1
# 2015-12-31            1           0            1          0
# 2016-01-31            0           0            0          0
# 2016-02-29            0           1            1          0
#
# [5 rows x 140 columns]

# %%
score  = all_data.columns[[x.startswith("C_Score") for x in all_data.columns]]
c_score = all_data[score]

# %%
c_score
# Out:
#             C_Score_AAPL  C_Score_APTV  C_Score_BAC  C_Score_BALL  \
# Date
# 2015-10-31             0             0            0             0
# 2015-11-30             1             1            1             1
# 2015-12-31             0             0            0             1
# 2016-01-31             0             0            0             0
# 2016-02-29             0             0            0             0
# ...                  ...           ...          ...           ...
# 2022-08-31             1             1            1             0
# 2022-09-30             0             0            0             0
# 2022-10-31             1             1            1             1
# 2022-11-30             0             1            1             1
# 2022-12-31             0             0            0             0
#
#             C_Score_BEP  C_Score_BKNG  C_Score_BMRN  C_Score_COST  \
# Date
# 2015-10-31            0             0             0             0
# 2015-11-30            0             1             0             1
# 2015-12-31            1             1             1             1
# 2016-01-31            0             0             0             0
# 2016-02-29            1             0             0             0
# ...                 ...           ...           ...           ...
# 2022-08-31            1             1             1             1
# 2022-09-30            0             0             0             0
# 2022-10-31            0             1             1             1
# 2022-11-30            0             1             1             1
# 2022-12-31            0             0             0             0
#
#             C_Score_CVS  C_Score_DE  C_Score_ETN  C_Score_GOOGL  C_Score_HD  \
# Date
# 2015-10-31            0           0            0              0           0
# 2015-11-30            0           1            1              1           1
# 2015-12-31            1           0            0              1           0
# 2016-01-31            0           0            0              0           0
# 2016-02-29            0           1            1              0           0
# ...                 ...         ...          ...            ...         ...
# 2022-08-31            1           1            1              1           1
# 2022-09-30            0           0            0              0           0
# 2022-10-31            0           1            1              0           1
# 2022-11-30            1           1            1              1           1
# 2022-12-31            0           0            0              0           0
#
#             C_Score_HIG  C_Score_MS  C_Score_MSFT  C_Score_PLD  C_Score_TT  \
# Date
# 2015-10-31            0           0             0            0           0
# 2015-11-30            1           1             1            1           1
# 2015-12-31            0           0             1            1           0
# 2016-01-31            0           0             0            0           0
# 2016-02-29            0           0             0            0           1
# ...                 ...         ...           ...          ...         ...
# 2022-08-31            0           1             1            1           1
# 2022-09-30            0           0             0            0           0
# 2022-10-31            1           1             0            1           1
# 2022-11-30            1           1             1            1           1
# 2022-12-31            0           0             0            0           0
#
#             C_Score_UNH  C_Score_V
# Date
# 2015-10-31            0          0
# 2015-11-30            0          1
# 2015-12-31            1          0
# 2016-01-31            0          0
# 2016-02-29            1          0
# ...                 ...        ...
# 2022-08-31            1          1
# 2022-09-30            0          0
# 2022-10-31            1          1
# 2022-11-30            0          1
# 2022-12-31            0          0
#
# [87 rows x 20 columns]
