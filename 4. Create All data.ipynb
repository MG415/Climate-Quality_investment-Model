# %%
import pandas as pd

# %%
ret = pd.read_csv('return_data.csv', index_col='Date', parse_dates=True)
ret
# Out:
#             ret_Fund  ret_AAPL  ret_APTV   ret_BAC  ret_BALL   ret_BEP  \
# Date
# 2015-09-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-10-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2015-11-30  0.052900  0.077120  0.159186  0.118742  0.118190 -0.071509
# 2015-12-31 -0.012727 -0.110228 -0.024465 -0.031705  0.047681  0.043027
# 2016-01-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2022-10-31  0.066239  0.109551  0.164429  0.193378  0.022144 -0.067732
# 2022-11-30  0.063492 -0.033027  0.171297  0.050222  0.139616 -0.019649
# 2022-12-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2023-01-31  0.006648 -0.025265  0.060186 -0.057135  0.038516  0.030399
# 2023-02-28 -0.027779  0.023183  0.028208 -0.033258 -0.031403 -0.092448
#
#             ret_BKNG  ret_BMRN  ret_COST   ret_CVS  ...   ret_ETN  ret_GOOGL  \
# ...

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90 entries, 2015-09-30 to 2023-02-28
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ret_Fund   89 non-null     float64
#  1   ret_AAPL   89 non-null     float64
#  2   ret_APTV   89 non-null     float64
#  3   ret_BAC    89 non-null     float64
#  4   ret_BALL   89 non-null     float64
#  5   ret_BEP    89 non-null     float64
#  6   ret_BKNG   89 non-null     float64
#  7   ret_BMRN   89 non-null     float64
#  8   ret_COST   89 non-null     float64
#  9   ret_CVS    89 non-null     float64
#  10  ret_DE     89 non-null     float64
#  11  ret_ETN    89 non-null     float64
#  12  ret_GOOGL  89 non-null     float64
#  13  ret_HD     89 non-null     float64
#  14  ret_HIG    89 non-null     float64
#  15  ret_MS     89 non-null     float64
#  16  ret_MSFT   89 non-null     float64
#  17  ret_PLD    89 non-null     float64
# ...

# %%
climate = pd.read_csv('climate_data.csv', index_col='Date', parse_dates=True)
climate
# Out:
#             cdd_18-France  cdd_18-Germany  cdd_18-India  cdd_18-Indonesia  \
# Date
# 2015-09-30        7.58800          1.4840        313.40             233.8
# 2015-10-31        0.59810          0.0000        280.10             263.1
# 2015-11-30        0.01212          0.0000        169.60             256.0
# 2015-12-31        0.00000          0.0000         88.83             250.7
# 2016-01-31        0.00000          0.0000         72.22             260.8
# ...                   ...             ...           ...               ...
# 2022-08-31      137.80000         90.4000        314.80             233.5
# 2022-09-30       35.78000          8.6410        292.60             231.5
# 2022-10-31        7.65100          0.1096        240.10             232.9
# 2022-11-30        0.06032          0.0000        132.40             229.1
# 2022-12-31        0.00000          0.0000         81.37             232.2
#
#             cdd_18-Italy  cdd_18-Japan  cdd_18-Korea  cdd_18-China  \
# ...

# %%
fmf = pd.read_csv('fama_data.csv', index_col='Date', parse_dates=True)
fmf
# Out:
#             Mkt-RF     SMB     HML     RMW     CMA      RF
# Date
# 2015-09-30 -0.0307 -0.0280  0.0056  0.0180 -0.0060  0.0000
# 2015-10-31  0.0775 -0.0205 -0.0046  0.0086  0.0055  0.0000
# 2015-11-30  0.0056  0.0329 -0.0042 -0.0271 -0.0103  0.0000
# 2015-12-31 -0.0217 -0.0297 -0.0261  0.0045  0.0003  0.0001
# 2016-01-31 -0.0577 -0.0348  0.0209  0.0280  0.0307  0.0001
# ...            ...     ...     ...     ...     ...     ...
# 2022-08-31 -0.0377  0.0149  0.0030 -0.0478  0.0130  0.0019
# 2022-09-30 -0.0935 -0.0097  0.0006 -0.0151 -0.0084  0.0019
# 2022-10-31  0.0783  0.0186  0.0805  0.0307  0.0652  0.0023
# 2022-11-30  0.0460 -0.0267  0.0138  0.0601  0.0311  0.0029
# 2022-12-31 -0.0641 -0.0016  0.0132  0.0009  0.0419  0.0033
#
# [88 rows x 6 columns]

# %%
all_data = pd.concat([fmf, 
                      climate, 
                      ret.reindex(fmf.index)], axis=1)

# %%
all_data
# Out:
#             Mkt-RF     SMB     HML     RMW     CMA      RF  cdd_18-France  \
# Date
# 2015-09-30 -0.0307 -0.0280  0.0056  0.0180 -0.0060  0.0000        7.58800
# 2015-10-31  0.0775 -0.0205 -0.0046  0.0086  0.0055  0.0000        0.59810
# 2015-11-30  0.0056  0.0329 -0.0042 -0.0271 -0.0103  0.0000        0.01212
# 2015-12-31 -0.0217 -0.0297 -0.0261  0.0045  0.0003  0.0001        0.00000
# 2016-01-31 -0.0577 -0.0348  0.0209  0.0280  0.0307  0.0001        0.00000
# ...            ...     ...     ...     ...     ...     ...            ...
# 2022-08-31 -0.0377  0.0149  0.0030 -0.0478  0.0130  0.0019      137.80000
# 2022-09-30 -0.0935 -0.0097  0.0006 -0.0151 -0.0084  0.0019       35.78000
# 2022-10-31  0.0783  0.0186  0.0805  0.0307  0.0652  0.0023        7.65100
# 2022-11-30  0.0460 -0.0267  0.0138  0.0601  0.0311  0.0029        0.06032
# 2022-12-31 -0.0641 -0.0016  0.0132  0.0009  0.0419  0.0033        0.00000
#
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88 entries, 2015-09-30 to 2022-12-31
# Data columns (total 99 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Mkt-RF                   88 non-null     float64
#  1   SMB                      88 non-null     float64
#  2   HML                      88 non-null     float64
#  3   RMW                      88 non-null     float64
#  4   CMA                      88 non-null     float64
#  5   RF                       88 non-null     float64
#  6   cdd_18-France            88 non-null     float64
#  7   cdd_18-Germany           88 non-null     float64
#  8   cdd_18-India             88 non-null     float64
#  9   cdd_18-Indonesia         88 non-null     float64
#  10  cdd_18-Italy             88 non-null     float64
#  11  cdd_18-Japan             88 non-null     float64
#  12  cdd_18-Korea             88 non-null     float64
# ...

# %%
all_data.to_csv('all_data.csv')
